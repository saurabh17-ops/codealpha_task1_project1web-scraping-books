# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/books.csv")

df.head()
# Out:
#                                    title  price  rating            category  \
# 0                   A Light in the Attic  51.77       3              Poetry
# 1                     Tipping the Velvet  53.74       1  Historical Fiction
# 2                             Soumission  50.10       1             Fiction
# 3                          Sharp Objects  47.82       4             Mystery
# 4  Sapiens: A Brief History of Humankind  54.23       5             History
#
#   availability                                        product_url
# 0     In stock  https://books.toscrape.com/catalogue/a-light-i...
# 1     In stock  https://books.toscrape.com/catalogue/tipping-t...
# 2     In stock  https://books.toscrape.com/catalogue/soumissio...
# 3     In stock  https://books.toscrape.com/catalogue/sharp-obj...
# 4     In stock  https://books.toscrape.com/catalogue/sapiens-a...

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.columns
# Out:
# Index(['title', 'price', 'rating', 'category', 'availability', 'product_url'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   str
#  1   price         1000 non-null   float64
#  2   rating        1000 non-null   int64
#  3   category      1000 non-null   str
#  4   availability  1000 non-null   str
#  5   product_url   1000 non-null   str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 47.0 KB

# %%
df.isnull().sum()
# Out:
# title           0
# price           0
# rating          0
# category        0
# availability    0
# product_url     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             price       rating
# count  1000.00000  1000.000000
# mean     35.07035     2.923000
# std      14.44669     1.434967
# min      10.00000     1.000000
# 25%      22.10750     2.000000
# 50%      35.98000     3.000000
# 75%      47.45750     4.000000
# max      59.99000     5.000000

# %%
average_price = df["price"].mean()

print(f"Average book price: £{average_price:.2f}")
# Out:
# Average book price: £35.07

# %%
df.loc[df["price"].idxmin()]
# Out:
# title                                  An Abundance of Katherines
# price                                                        10.0
# rating                                                          5
# category                                              Young Adult
# availability                                             In stock
# product_url     https://books.toscrape.com/catalogue/an-abunda...
# Name: 638, dtype: object

# %%
df.loc[df["price"].idxmax()]
# Out:
# title                          The Perfect Play (Play by Play #1)
# price                                                       59.99
# rating                                                          3
# category                                                  Romance
# availability                                             In stock
# product_url     https://books.toscrape.com/catalogue/the-perfe...
# Name: 648, dtype: object

# %%
df["rating"].value_counts().sort_index()
# Out:
# rating
# 1    226
# 2    196
# 3    203
# 4    179
# 5    196
# Name: count, dtype: int64

# %%
rating_counts = df["rating"].value_counts().sort_index()

rating_counts.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribution of Book Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Books")

plt.show()

# %%
df["price"].plot(
    kind="hist",
    bins=20,
    figsize=(8, 5)
)

plt.title("Distribution of Book Prices")
plt.xlabel("Price (£)")
plt.ylabel("Number of Books")

plt.show()

# %%
df.sort_values(
    by="price",
    ascending=False
).head(10)
# Out:
#                                                  title  price  rating  \
# 648                 The Perfect Play (Play by Play #1)  59.99       3
# 617                  Last One Home (New Beginnings #1)  59.98       3
# 860                   Civilization and Its Discontents  59.95       2
# 560                     The Barefoot Contessa Cookbook  59.92       5
# 366                          The Diary of a Young Girl  59.90       3
# 657  The Bone Hunters (Lexy Vaughan & Steven Macaul...  59.71       3
# 133  Thomas Jefferson and the Tripoli Pirates: The ...  59.64       1
# 387                      Boar Island (Anna Pigeon #19)  59.48       3
# 549  The Man Who Mistook His Wife for a Hat and Oth...  59.45       4
# 393                          The Improbability of Love  59.45       1
#
#            category availability  \
# 648         Romance     In stock
# 617         Fiction     In stock
# 860      Psychology     In stock
# 560  Food and Drink     In stock
# ...

# %%
df.sort_values(
    by="price",
    ascending=True
).head(10)
# Out:
#                                                  title  price  rating  \
# 638                         An Abundance of Katherines  10.00       5
# 501                              The Origin of Species  10.01       4
# 716  The Tipping Point: How Little Things Can Make ...  10.02       2
# 84                                            Patience  10.16       3
# 302                               Greek Mythic History  10.23       5
# 558  The Fellowship of the Ring (The Lord of the Ri...  10.27       2
# 479                                  History of Beauty  10.29       4
# 242  The Lucifer Effect: Understanding How Good Peo...  10.40       1
# 434  NaNo What Now? Finding your editing process, r...  10.41       4
# 274                                       Pet Sematary  10.56       3
#
#            category availability  \
# 638     Young Adult     In stock
# 501         Science     In stock
# 716         Unknown     In stock
# 84   Sequential Art     In stock
# ...

# %%
df = pd.read_csv("../data/books.csv")

df.head()
# Out:
#                                    title  price  rating            category  \
# 0                   A Light in the Attic  51.77       3              Poetry
# 1                     Tipping the Velvet  53.74       1  Historical Fiction
# 2                             Soumission  50.10       1             Fiction
# 3                          Sharp Objects  47.82       4             Mystery
# 4  Sapiens: A Brief History of Humankind  54.23       5             History
#
#   availability                                        product_url
# 0     In stock  https://books.toscrape.com/catalogue/a-light-i...
# 1     In stock  https://books.toscrape.com/catalogue/tipping-t...
# 2     In stock  https://books.toscrape.com/catalogue/soumissio...
# 3     In stock  https://books.toscrape.com/catalogue/sharp-obj...
# 4     In stock  https://books.toscrape.com/catalogue/sapiens-a...

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.columns
# Out:
# Index(['title', 'price', 'rating', 'category', 'availability', 'product_url'], dtype='str')

# %%
df["category"].value_counts()
# Out:
# category
# Unknown               220
# Nonfiction            110
# Sequential Art         75
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                34
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Travel                 11
# Thriller               11
# Philosophy             11
# Humor                  10
# Autobiography           9
# Art                     8
# Religion                7
# Psychology              7
# Spirituality            6
# New Adult               6
# Christian Fiction       6
# Self Help               5
# Biography               5
# Sports and Games        5
# Health                  4
# ...

# %%
category_counts = df["category"].value_counts()

category_counts.head(10)
# Out:
# category
# Unknown           220
# Nonfiction        110
# Sequential Art     75
# Fiction            65
# Young Adult        54
# Fantasy            48
# Romance            34
# Mystery            32
# Food and Drink     30
# Childrens          29
# Name: count, dtype: int64

# %%
category_counts.head(10).plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Top 10 Book Categories by Number of Books")
plt.xlabel("Category")
plt.ylabel("Number of Books")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
category_price = (
    df.groupby("category")["price"]
    .mean()
    .sort_values(ascending=False)
)

category_price.head(10)
# Out:
# category
# Suspense            58.330000
# Novels              54.810000
# Politics            53.613333
# Health              51.452500
# New Adult           46.383333
# Christian           42.496667
# Sports and Games    41.166000
# Self Help           40.620000
# Travel              39.794545
# Fantasy             39.593958
# Name: price, dtype: float64

# %%
category_price.head(10).plot(
    kind="bar",
    figsize=(10, 6)
)

plt.title("Top 10 Categories by Average Book Price")
plt.xlabel("Category")
plt.ylabel("Average Price (£)")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.columns
# Out:
# Index(['title', 'price', 'rating', 'category', 'availability', 'product_url'], dtype='str')

# %%
df.isnull().sum()
# Out:
# title           0
# price           0
# rating          0
# category        0
# availability    0
# product_url     0
# dtype: int64

# %%
df["category"].value_counts().head(10)
# Out:
# category
# Unknown           220
# Nonfiction        110
# Sequential Art     75
# Fiction            65
# Young Adult        54
# Fantasy            48
# Romance            34
# Mystery            32
# Food and Drink     30
# Childrens          29
# Name: count, dtype: int64

# %%
df[["title", "category"]].head(20)
# Out:
#                                                 title            category
# 0                                A Light in the Attic              Poetry
# 1                                  Tipping the Velvet  Historical Fiction
# 2                                          Soumission             Fiction
# 3                                       Sharp Objects             Mystery
# 4               Sapiens: A Brief History of Humankind             History
# 5                                     The Requiem Red         Young Adult
# 6   The Dirty Little Secrets of Getting Your Dream...            Business
# 7   The Coming Woman: A Novel Based on the Life of...             Unknown
# 8   The Boys in the Boat: Nine Americans and Their...             Unknown
# 9                                     The Black Maria              Poetry
# 10     Starving Hearts (Triangular Trade Trilogy, #1)             Unknown
# 11                              Shakespeare's Sonnets              Poetry
# ...

# %%
df["category"].unique()
# Out:
# <StringArray>
# [            'Poetry', 'Historical Fiction',            'Fiction',
#             'Mystery',            'History',        'Young Adult',
#            'Business',            'Unknown',     'Sequential Art',
#               'Music',    'Science Fiction',           'Politics',
#              'Travel',           'Thriller',     'Food and Drink',
#             'Romance',          'Childrens',         'Nonfiction',
#                 'Art',       'Spirituality',         'Philosophy',
#           'New Adult',       'Contemporary',            'Fantasy',
#             'Science',             'Health',             'Horror',
#           'Self Help',           'Religion',          'Christian',
#               'Crime',      'Autobiography',  'Christian Fiction',
#           'Biography',     'Womens Fiction',            'Erotica',
#            'Cultural',         'Psychology',              'Humor',
#          'Historical',             'Novels',      'Short Stories',
# ...

# %%
len(df["category"].unique())
# Out:
# 49

# %%
df[["title", "category"]].head(20)
# Out:
#                                                 title            category
# 0                                A Light in the Attic              Poetry
# 1                                  Tipping the Velvet  Historical Fiction
# 2                                          Soumission             Fiction
# 3                                       Sharp Objects             Mystery
# 4               Sapiens: A Brief History of Humankind             History
# 5                                     The Requiem Red         Young Adult
# 6   The Dirty Little Secrets of Getting Your Dream...            Business
# 7   The Coming Woman: A Novel Based on the Life of...             Unknown
# 8   The Boys in the Boat: Nine Americans and Their...             Unknown
# 9                                     The Black Maria              Poetry
# 10     Starving Hearts (Triangular Trade Trilogy, #1)             Unknown
# 11                              Shakespeare's Sonnets              Poetry
# ...

# %%
df["category"].value_counts()
# Out:
# category
# Unknown               220
# Nonfiction            110
# Sequential Art         75
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                34
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Travel                 11
# Thriller               11
# Philosophy             11
# Humor                  10
# Autobiography           9
# Art                     8
# Religion                7
# Psychology              7
# Spirituality            6
# New Adult               6
# Christian Fiction       6
# Self Help               5
# Biography               5
# Sports and Games        5
# Health                  4
# ...

# %%
df = pd.read_csv("../data/books.csv")
df["category"].value_counts()
# Out:
# category
# Unknown               220
# Nonfiction            110
# Sequential Art         75
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                34
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Travel                 11
# Thriller               11
# Philosophy             11
# Humor                  10
# Autobiography           9
# Art                     8
# Religion                7
# Psychology              7
# Spirituality            6
# New Adult               6
# Christian Fiction       6
# Self Help               5
# Biography               5
# Sports and Games        5
# Health                  4
# ...

# %%
df["category"].unique()
# Out:
# <StringArray>
# [            'Poetry', 'Historical Fiction',            'Fiction',
#             'Mystery',            'History',        'Young Adult',
#            'Business',            'Unknown',     'Sequential Art',
#               'Music',    'Science Fiction',           'Politics',
#              'Travel',           'Thriller',     'Food and Drink',
#             'Romance',          'Childrens',         'Nonfiction',
#                 'Art',       'Spirituality',         'Philosophy',
#           'New Adult',       'Contemporary',            'Fantasy',
#             'Science',             'Health',             'Horror',
#           'Self Help',           'Religion',          'Christian',
#               'Crime',      'Autobiography',  'Christian Fiction',
#           'Biography',     'Womens Fiction',            'Erotica',
#            'Cultural',         'Psychology',              'Humor',
#          'Historical',             'Novels',      'Short Stories',
# ...

# %%
df[df["category"] == "Add a comment"][["title", "product_url"]].head(10)
# Out:
# Empty DataFrame
# Columns: [title, product_url]
# Index: []

# %%
df[df["category"] == "Default"][["title", "product_url"]].head(10)
# Out:
# Empty DataFrame
# Columns: [title, product_url]
# Index: []

# %%
problem_url = df.loc[7, "product_url"]
problem_url
# Out:
# 'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html'

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get(problem_url)

soup = BeautifulSoup(response.text, "html.parser")

for i, item in enumerate(soup.select("ul.breadcrumb li")):
    print(i, item.get_text(" ", strip=True))
# Out:
# 0 Home
# 1 Books
# 2 Default
# 3 The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull

# %%
print(soup.select("ul.breadcrumb li")[2])
# Out:
# <li>
# <a href="../category/books/default_15/index.html">Default</a>
# </li>

# %%
df["category"].value_counts().loc[
    lambda x: x.index.isin(["Default", "Add a comment", "Some Category", "Unknown"])
]
# Out:
# category
# Unknown    220
# Name: count, dtype: int64

# %%
df["category"] = df["category"].replace(
    ["Default", "Add a comment"],
    "Unknown"
)

# %%
df["category"].value_counts().head(15)
# Out:
# category
# Unknown               220
# Nonfiction            110
# Sequential Art         75
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                34
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Name: count, dtype: int64

# %%
df[df["category"].isin(["Default", "Add a comment"])]
# Out:
# Empty DataFrame
# Columns: [title, price, rating, category, availability, product_url]
# Index: []

# %% [markdown]
# df["category"] = df["category"].replace(
#     ["Default", "Add a comment"],
#     "Unknown"
# )

# %%
df["category"].value_counts().head(15)
# Out:
# category
# Unknown               220
# Nonfiction            110
# Sequential Art         75
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                34
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Poetry                 19
# Classics               19
# History                18
# Horror                 17
# Name: count, dtype: int64

# %%
df[df["category"].isin(["Default", "Add a comment"])]
# Out:
# Empty DataFrame
# Columns: [title, price, rating, category, availability, product_url]
# Index: []

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.describe()
# Out:
#             price       rating
# count  1000.00000  1000.000000
# mean     35.07035     2.923000
# std      14.44669     1.434967
# min      10.00000     1.000000
# 25%      22.10750     2.000000
# 50%      35.98000     3.000000
# 75%      47.45750     4.000000
# max      59.99000     5.000000

# %%
df["price"].mean()
# Out:
# np.float64(35.07035)

# %%
df.loc[df["price"].idxmin(), ["title", "price"]]
# Out:
# title    An Abundance of Katherines
# price                          10.0
# Name: 638, dtype: object

# %%
df.loc[df["price"].idxmax(), ["title", "price"]]
# Out:
# title    The Perfect Play (Play by Play #1)
# price                                 59.99
# Name: 648, dtype: object

# %%
df["rating"].value_counts().sort_index()
# Out:
# rating
# 1    226
# 2    196
# 3    203
# 4    179
# 5    196
# Name: count, dtype: int64

# %%
rating_counts = df["rating"].value_counts().sort_index()

plt.figure(figsize=(8, 5))

plt.bar(rating_counts.index, rating_counts.values)

plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.title("Number of Books by Rating")

plt.xticks([1, 2, 3, 4, 5])

plt.savefig("../images/rating_distribution.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["price"], bins=20)

plt.xlabel("Price (£)")
plt.ylabel("Number of Books")
plt.title("Distribution of Book Prices")

plt.show()

# %%
category_counts = (
    df[df["category"] != "Unknown"]["category"]
    .value_counts()
    .head(10)
)

plt.figure(figsize=(10, 6))

plt.barh(
    category_counts.index[::-1],
    category_counts.values[::-1]
)

plt.xlabel("Number of Books")
plt.ylabel("Category")
plt.title("Top 10 Book Categories")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df["price"], df["rating"])

plt.xlabel("Price (£)")
plt.ylabel("Rating")
plt.title("Book Price vs Rating")

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df["price"], df["rating"])

plt.xlabel("Price (£)")
plt.ylabel("Rating")
plt.title("Book Price vs Rating")

plt.show()

# %%
correlation = df["price"].corr(df["rating"])

print("Correlation between Price and Rating:", correlation)
# Out:
# Correlation between Price and Rating: 0.028166239485872963

# %%
availability_counts = df["availability"].value_counts()

print(availability_counts)
# Out:
# availability
# In stock    1000
# Name: count, dtype: int64

# %%
category_price = (
    df[df["category"] != "Unknown"]
    .groupby("category")["price"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

print(category_price)
# Out:
# category
# Suspense            58.330000
# Novels              54.810000
# Politics            53.613333
# Health              51.452500
# New Adult           46.383333
# Christian           42.496667
# Sports and Games    41.166000
# Self Help           40.620000
# Travel              39.794545
# Fantasy             39.593958
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    category_price.index[::-1],
    category_price.values[::-1]
)

plt.xlabel("Average Price (£)")
plt.ylabel("Category")
plt.title("Top 10 Categories by Average Book Price")

plt.show()

# %%
top_expensive_books = (
    df[["title", "price", "rating", "category"]]
    .sort_values("price", ascending=False)
    .head(10)
)

top_expensive_books
# Out:
#                                                  title  price  rating  \
# 648                 The Perfect Play (Play by Play #1)  59.99       3
# 617                  Last One Home (New Beginnings #1)  59.98       3
# 860                   Civilization and Its Discontents  59.95       2
# 560                     The Barefoot Contessa Cookbook  59.92       5
# 366                          The Diary of a Young Girl  59.90       3
# 657  The Bone Hunters (Lexy Vaughan & Steven Macaul...  59.71       3
# 133  Thomas Jefferson and the Tripoli Pirates: The ...  59.64       1
# 387                      Boar Island (Anna Pigeon #19)  59.48       3
# 549  The Man Who Mistook His Wife for a Hat and Oth...  59.45       4
# 393                          The Improbability of Love  59.45       1
#
#            category
# 648         Romance
# 617         Fiction
# 860      Psychology
# 560  Food and Drink
# 366      Nonfiction
# 657        Thriller
# 133         History
# 387         Mystery
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/books.csv")

df.head()
# Out:
#                                    title  price  rating            category  \
# 0                   A Light in the Attic  51.77       3              Poetry
# 1                     Tipping the Velvet  53.74       1  Historical Fiction
# 2                             Soumission  50.10       1             Fiction
# 3                          Sharp Objects  47.82       4             Mystery
# 4  Sapiens: A Brief History of Humankind  54.23       5             History
#
#   availability                                        product_url
# 0     In stock  https://books.toscrape.com/catalogue/a-light-i...
# 1     In stock  https://books.toscrape.com/catalogue/tipping-t...
# 2     In stock  https://books.toscrape.com/catalogue/soumissio...
# 3     In stock  https://books.toscrape.com/catalogue/sharp-obj...
# 4     In stock  https://books.toscrape.com/catalogue/sapiens-a...

# %%
rating_counts = df["rating"].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(rating_counts.index, rating_counts.values)
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.title("Number of Books by Rating")
plt.xticks([1, 2, 3, 4, 5])

plt.savefig("../images/rating_distribution.png", bbox_inches="tight")
plt.show()

# %%
rating_counts = df["rating"].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(rating_counts.index, rating_counts.values)
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.title("Number of Books by Rating")
plt.xticks([1, 2, 3, 4, 5])
plt.savefig("../images/rating_distribution.png", bbox_inches="tight")
plt.show()

# %%
rating_counts = df["rating"].value_counts().sort_index()

plt.figure(figsize=(8, 5))
plt.bar(rating_counts.index, rating_counts.values)
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.title("Number of Books by Rating")
plt.xticks([1, 2, 3, 4, 5])

plt.savefig("../images/rating_distribution.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df["price"], bins=20)
plt.xlabel("Price (£)")
plt.ylabel("Number of Books")
plt.title("Distribution of Book Prices")

plt.savefig("../images/price_distribution.png", bbox_inches="tight")
plt.show()

# %%
category_counts = (
    df[df["category"] != "Unknown"]
    ["category"]
    .value_counts()
    .head(10)
)

plt.figure(figsize=(10, 6))
plt.barh(
    category_counts.index[::-1],
    category_counts.values[::-1]
)
plt.xlabel("Number of Books")
plt.ylabel("Category")
plt.title("Top 10 Book Categories")

plt.savefig("../images/top_categories.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df["price"], df["rating"])
plt.xlabel("Price (£)")
plt.ylabel("Rating")
plt.title("Book Price vs Rating")

plt.savefig("../images/price_vs_rating.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    category_price.index[::-1],
    category_price.values[::-1]
)

plt.xlabel("Average Price (£)")
plt.ylabel("Category")
plt.title("Top 10 Categories by Average Book Price")

plt.savefig(
    "../images/category_average_price.png",
    bbox_inches="tight"
)

plt.show()

# %%
category_price = (
    df[df["category"] != "Unknown"]
    .groupby("category")["price"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

print(category_price)
# Out:
# category
# Suspense            58.330000
# Novels              54.810000
# Politics            53.613333
# Health              51.452500
# New Adult           46.383333
# Christian           42.496667
# Sports and Games    41.166000
# Self Help           40.620000
# Travel              39.794545
# Fantasy             39.593958
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    category_price.index[::-1],
    category_price.values[::-1]
)

plt.xlabel("Average Price (£)")
plt.ylabel("Category")
plt.title("Top 10 Categories by Average Book Price")

plt.savefig(
    "../images/category_average_price.png",
    bbox_inches="tight"
)

plt.show()
